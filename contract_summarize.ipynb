# %%
# !pip install openai tiktoken chromadb langchain

# Set env var OPENAI_API_KEY or load from a .env file
import dotenv

dotenv.load_dotenv()
# Out:
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 664.7 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 45.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import WebBaseLoader
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("data/summarization_text/6_Terms-and-Conditions-of-License-Agreements.pdf")
loader.load()
# Out:
# [Document(page_content='/i255/1 /2 /3 /4 /5 /6 /7 /i255 /i255 /i255\n/9 /10 /11 /12/4 /i255/i255 /i255/13 /6 /14 /i255/i255 /i255/15 /2 /6 /14 /5 /9 /5 /2 /6 /4 /i255/i255 /i255/2 /16 /i255/i255 /i255/1 /2 /3 /4 /5 /6 /7 /i255/i255 /i255/17 /5 /15 /10 /6 /4 /10 /i255/i255 /i255/13 /7 /11 /10 /10 /12/10 /6 /9 /i255 /i255 /i255 /i255 /i255\n/18 /19 /20 /i255/i255 /i255/21 /20 /22 /23 /24 /25 /26 /27 /28 /19 /25 /29 /i255/i255 /i255/30 /20 /24 /31 /20 /20 /27 /i255/i255 /i255/24 /19 /20 /i255/i255 /i255/21 /20 /28 /25 /32 /20 /27 /24 /i255/i255 /i255/23 /27 /32 /i255/i255 /i255/33 /26 /21 /27 /20 /22 /22 /i255/i255 /i255/18 /20 /34 /19 /i255/i255 /i255/25 /28 /i255/i255 /i255/24 /19 /23 /24 /i255/i255 /i255/26 /35 /i255/i255 /i255/22 /25 /34 /20 /27 /28 /20 /20 /i255/i255 /i255/23 /27 /32 /i255/i255 /i255/22 /25 /34 /20 /27 /28 /26 /21 /36 /i255/i255 /i255/18 /19 /25 /28 /i255/i255 /i255 /i255/37 /38 /21 /20 /20 /39 /20 /27 /24 /i255 /i255 /i255\n/32 /26 /20 /28 /i255/i255 /i255/27 /26 
# ...

# %%
import pytesseract
from PIL import Image
import pdf2image

def extract_text_with_ocr(pdf_path):
    # Convert PDF to images (one image per page)
    pages = pdf2image.convert_from_path(pdf_path)
    text = ""

    for page in pages:
        # Extract text from each page image using OCR
        text += pytesseract.image_to_string(page)

    return text

# Example usage
pdf_text = extract_text_with_ocr("data/summarization_text/6_Terms-and-Conditions-of-License-Agreements.pdf")
print(pdf_text)
# Out:
# /Users/yangqingyun/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py:104: RuntimeWarning: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 10.1.0
# Pillow version: 8.4.0
#   warnings.warn(str(v), RuntimeWarning)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/l8/b1n18c_s19n6qtljq2fztnqr0000gn/T/ipykernel_45878/1262888909.py in <module>
# ----> 1 import pytesseract
#       2 from PIL import Image
#       3 import pdf2image
#       4
#       5 def extract_text_with_ocr(pdf_path):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pytesseract/__init__.py in <module>
#       1 # flake8: noqa: F401
# ----> 2 from .pytesseract import ALTONotSupported
#       3 from .pytesseract import get_languages
#       4 from .pytesseract import get_tesseract_version
#       5 from .pytesseract import image_to_alto_xml
#
# ...
